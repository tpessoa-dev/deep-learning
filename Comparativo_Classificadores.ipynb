# %% [markdown]
# <a href="https://colab.research.google.com/github/tpessoa-dev/deep-learning/blob/main/Comparativo_Classificadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sklearn_extensions
# Out:
# Requirement already satisfied: sklearn_extensions in /usr/local/lib/python3.7/dist-packages (0.0.2)
# Requirement already satisfied: scipy>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_extensions) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.15 in /usr/local/lib/python3.7/dist-packages (from sklearn_extensions) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_extensions) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15->sklearn_extensions) (1.0.1)

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

"""
=====================
Classifier comparison
=====================

A comparison of a several classifiers in scikit-learn on synthetic datasets.
The point of this example is to illustrate the nature of decision boundaries
of different classifiers.
This should be taken with a grain of salt, as the intuition conveyed by
these examples does not necessarily carry over to real datasets.

Particularly in high-dimensional spaces, data can more easily be separated
linearly and the simplicity of classifiers such as naive Bayes and linear SVMs
might lead to better generalization than is achieved by other classifiers.

The plots show training points in solid colors and testing points
semi-transparent. The lower right shows the classification accuracy on the test
set.
"""
print(__doc__)


# Code source: Gaël Varoquaux
#              Andreas Müller
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification, make_blobs
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras import backend as K
from keras import metrics
from keras import regularizers
from tensorflow.python.client import device_lib

from xgboost import XGBClassifier

#pip install sklearn-extensions
from sklearn_extensions.extreme_learning_machines.elm import GenELMClassifier
from sklearn_extensions.extreme_learning_machines.random_layer import RBFRandomLayer, MLPRandomLayer
#conda install -c anaconda tensorflow-gpu

#Quantidade de Camadas Escondidas padrão
nh = 10

h = .02  # step size in the mesh

#Cria camada aleatório com função de ativação RBF 
srhl_rbf = RBFRandomLayer(n_hidden=nh*2, rbf_width=0.1, random_state=0)

names = ["ELM - RBF","Keras-MLP","Nearest Neighbors", "RBF SVM", 
         "Decision Tree", "Random Forest",
         #"Neural Net - ReLU e Adam"
         "XGBoost",
         "Naive Bayes" ]

# kernel_regularizer=regularizers.l2(0.2))
#, kernel_regularizer=regularizers.l2(0.01)
kmlp = Sequential()
kmlp.add(Dense(8, input_dim=2, activation='relu',  kernel_initializer='normal'))
kmlp.add(Dense(128, activation='relu'))
kmlp.add(Dense(128, activation='relu'))
kmlp.add(Dense(1, activation='sigmoid'))
kmlp.compile(optimizer = "adam", loss='binary_crossentropy', metrics=['binary_accuracy'])

classifiers = [
    GenELMClassifier(hidden_layer=srhl_rbf),
    kmlp,
    KNeighborsClassifier(3),
    SVC(gamma=2, C=1),    
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10),    
    #MLPClassifier(alpha=0.5, max_iter=30000, hidden_layer_sizes=200, activation='relu', solver='adam', verbose=True ),
    XGBClassifier(n_estimators=100),
    GaussianNB()]

X, y = make_classification(n_features=2, n_redundant=0, n_informative=2,
                           random_state=1, n_clusters_per_class=1)
rng = np.random.RandomState(2)
X += 2 * rng.uniform(size=X.shape)
linearly_separable = (X, y)

datasets = [make_moons(noise=0.4, random_state=0),
            make_circles(noise=0.2, factor=0.5, random_state=1),
            linearly_separable,
            make_circles( noise=0.05, random_state=3)
            ]

figure = plt.figure(figsize=(27, 9))
i = 1
# iterate over datasets
for ds_cnt, ds in enumerate(datasets):
    # preprocess dataset, split into training and test part
    X, y = ds
    X = StandardScaler().fit_transform(X)
    X_train, X_test, y_train, y_test = \
        train_test_split(X, y, test_size=.4, random_state=42)

    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    # just plot the dataset first
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])
    ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
    if ds_cnt == 0:
        ax.set_title("Input data")
    # Plot the training points
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright,
               edgecolors='k')
    # Plot the testing points
    ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6,
               edgecolors='k')
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xticks(())
    ax.set_yticks(())
    i += 1

    # iterate over classifiers
    for name, clf in zip(names, classifiers):
        ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
        
        if name == "Keras-MLP":
            clf.fit(X_train, y_train, epochs=100, batch_size=10  )
        else:
            clf.fit(X_train, y_train)
        
        if name == "Keras-MLP":
            score = clf.evaluate(X_test, y_test) 
            score = score[1]
        else:
            score = clf.score(X_test, y_test)

        # Plot the decision boundary. For that, we will assign a color to each
        # point in the mesh [x_min, x_max]x[y_min, y_max].
       
        if hasattr(clf, "decision_function"):
            Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
        elif name == "Keras-MLP":
            #print(np.c_[xx.ravel(), yy.ravel()])
            aux = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])            
            Z =aux
        else:
            Z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]

        # Put the result into a color plot
        Z = Z.reshape(xx.shape)
        ax.contourf(xx, yy, Z, cmap=cm, alpha=.8)

        # Plot the training points
        ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright,
                   edgecolors='k')
        # Plot the testing points
        ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright,
                   edgecolors='k', alpha=0.6)

        ax.set_xlim(xx.min(), xx.max())
        ax.set_ylim(yy.min(), yy.max())
        ax.set_xticks(())
        ax.set_yticks(())
        if ds_cnt == 0:
            ax.set_title(name)
        ax.text(xx.max() - .3, yy.min() + .3, ('%.2f' % score).lstrip('0'),
                size=15, horizontalalignment='right')
        i += 1

plt.tight_layout()
plt.show()
# Out:
# =====================
# Classifier comparison
# =====================
#
# A comparison of a several classifiers in scikit-learn on synthetic datasets.
# The point of this example is to illustrate the nature of decision boundaries
# of different classifiers.
# This should be taken with a grain of salt, as the intuition conveyed by
# these examples does not necessarily carry over to real datasets.
#
# Particularly in high-dimensional spaces, data can more easily be separated
# linearly and the simplicity of classifiers such as naive Bayes and linear SVMs
# might lead to better generalization than is achieved by other classifiers.
#
# The plots show training points in solid colors and testing points
# semi-transparent. The lower right shows the classification accuracy on the test
# set.
#
# Epoch 1/100
# 6/6 [==============================] - 1s 5ms/step - loss: 0.6894 - binary_accuracy: 0.6736
# Epoch 2/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6739 - binary_accuracy: 0.8624
# Epoch 3/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6661 - binary_accuracy: 0.7367
# Epoch 4/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6499 - binary_accuracy: 0.7095
# Epoch 5/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6256 - binary_accuracy: 0.8083
# Epoch 6/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5864 - binary_accuracy: 0.8131
# Epoch 7/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5825 - binary_accuracy: 0.7605
# Epoch 8/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5705 - binary_accuracy: 0.7117
# Epoch 9/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5152 - binary_accuracy: 0.7883
# Epoch 10/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4593 - binary_accuracy: 0.8002
# Epoch 11/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4754 - binary_accuracy: 0.7657
# Epoch 12/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4563 - binary_accuracy: 0.7662
# Epoch 13/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3798 - binary_accuracy: 0.7979
# Epoch 14/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4897 - binary_accuracy: 0.7238
# Epoch 15/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4517 - binary_accuracy: 0.7764
# Epoch 16/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3835 - binary_accuracy: 0.8090
# Epoch 17/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4299 - binary_accuracy: 0.7717
# Epoch 18/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3075 - binary_accuracy: 0.8581
# Epoch 19/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3994 - binary_accuracy: 0.7990
# Epoch 20/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4097 - binary_accuracy: 0.7781
# Epoch 21/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4044 - binary_accuracy: 0.8040
# Epoch 22/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3799 - binary_accuracy: 0.7969
# Epoch 23/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4165 - binary_accuracy: 0.7774
# Epoch 24/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3863 - binary_accuracy: 0.7743
# Epoch 25/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3532 - binary_accuracy: 0.7971
# Epoch 26/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3553 - binary_accuracy: 0.7774
# Epoch 27/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3936 - binary_accuracy: 0.7631
# Epoch 28/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3054 - binary_accuracy: 0.8538
# Epoch 29/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3592 - binary_accuracy: 0.7764
# Epoch 30/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3221 - binary_accuracy: 0.8302
# Epoch 31/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3064 - binary_accuracy: 0.8450
# Epoch 32/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3893 - binary_accuracy: 0.7488
# Epoch 33/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3632 - binary_accuracy: 0.7814
# Epoch 34/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2735 - binary_accuracy: 0.8776
# Epoch 35/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3117 - binary_accuracy: 0.8231
# Epoch 36/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2856 - binary_accuracy: 0.8464
# Epoch 37/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3572 - binary_accuracy: 0.8352
# Epoch 38/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3011 - binary_accuracy: 0.8538
# Epoch 39/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2756 - binary_accuracy: 0.8605
# Epoch 40/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3090 - binary_accuracy: 0.8426
# Epoch 41/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2813 - binary_accuracy: 0.8988
# Epoch 42/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2472 - binary_accuracy: 0.8976
# Epoch 43/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2778 - binary_accuracy: 0.8888
# Epoch 44/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2317 - binary_accuracy: 0.9148
# Epoch 45/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2637 - binary_accuracy: 0.8869
# Epoch 46/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2221 - binary_accuracy: 0.9231
# Epoch 47/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2524 - binary_accuracy: 0.8752
# Epoch 48/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2560 - binary_accuracy: 0.8810
# Epoch 49/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2458 - binary_accuracy: 0.8686
# Epoch 50/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2373 - binary_accuracy: 0.9119
# Epoch 51/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2135 - binary_accuracy: 0.9157
# Epoch 52/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2901 - binary_accuracy: 0.8424
# Epoch 53/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1986 - binary_accuracy: 0.9238
# Epoch 54/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1653 - binary_accuracy: 0.9407
# Epoch 55/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2131 - binary_accuracy: 0.9043
# Epoch 56/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2180 - binary_accuracy: 0.8871
# Epoch 57/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1704 - binary_accuracy: 0.9598
# Epoch 58/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2194 - binary_accuracy: 0.9421
# Epoch 59/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1801 - binary_accuracy: 0.9131
# Epoch 60/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2312 - binary_accuracy: 0.8786
# Epoch 61/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1726 - binary_accuracy: 0.9581
# Epoch 62/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1672 - binary_accuracy: 0.9486
# Epoch 63/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1824 - binary_accuracy: 0.9421
# Epoch 64/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1887 - binary_accuracy: 0.9390
# Epoch 65/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1707 - binary_accuracy: 0.9562
# Epoch 66/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1328 - binary_accuracy: 0.9729
# Epoch 67/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1763 - binary_accuracy: 0.9645
# Epoch 68/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1567 - binary_accuracy: 0.9490
# Epoch 69/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1568 - binary_accuracy: 0.9467
# Epoch 70/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1711 - binary_accuracy: 0.9438
# Epoch 71/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1439 - binary_accuracy: 0.9652
# Epoch 72/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1902 - binary_accuracy: 0.9283
# Epoch 73/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1391 - binary_accuracy: 0.9426
# Epoch 74/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1447 - binary_accuracy: 0.9545
# Epoch 75/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1393 - binary_accuracy: 0.9617
# Epoch 76/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1803 - binary_accuracy: 0.9205
# Epoch 77/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1145 - binary_accuracy: 0.9729
# Epoch 78/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1623 - binary_accuracy: 0.9307
# Epoch 79/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1139 - binary_accuracy: 0.9645
# Epoch 80/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1379 - binary_accuracy: 0.9502
# Epoch 81/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1484 - binary_accuracy: 0.9474
# Epoch 82/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1111 - binary_accuracy: 0.9764
# Epoch 83/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1394 - binary_accuracy: 0.9450
# Epoch 84/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1168 - binary_accuracy: 0.9617
# Epoch 85/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1103 - binary_accuracy: 0.9610
# Epoch 86/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1483 - binary_accuracy: 0.9307
# Epoch 87/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1965 - binary_accuracy: 0.9140
# Epoch 88/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2018 - binary_accuracy: 0.9021
# Epoch 89/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1789 - binary_accuracy: 0.9283
# Epoch 90/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1256 - binary_accuracy: 0.9581
# Epoch 91/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1181 - binary_accuracy: 0.9562
# Epoch 92/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1325 - binary_accuracy: 0.9545
# Epoch 93/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1053 - binary_accuracy: 0.9857
# Epoch 94/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1166 - binary_accuracy: 0.9581
# Epoch 95/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1210 - binary_accuracy: 0.9562
# Epoch 96/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1147 - binary_accuracy: 0.9531
# Epoch 97/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1668 - binary_accuracy: 0.9283
# Epoch 98/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1498 - binary_accuracy: 0.9355
# Epoch 99/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0827 - binary_accuracy: 0.9829
# Epoch 100/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0971 - binary_accuracy: 0.9745
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3511 - binary_accuracy: 0.9000
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# Epoch 1/100
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7194 - binary_accuracy: 0.4667
# Epoch 2/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.8228 - binary_accuracy: 0.5000
# Epoch 3/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.1288 - binary_accuracy: 0.5500
# Epoch 4/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7776 - binary_accuracy: 0.6667
# Epoch 5/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6381 - binary_accuracy: 0.7167
# Epoch 6/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5790 - binary_accuracy: 0.7333
# Epoch 7/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5604 - binary_accuracy: 0.7500
# Epoch 8/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5430 - binary_accuracy: 0.7500
# Epoch 9/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5357 - binary_accuracy: 0.7500
# Epoch 10/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5204 - binary_accuracy: 0.7500
# Epoch 11/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5123 - binary_accuracy: 0.7500
# Epoch 12/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5048 - binary_accuracy: 0.7500
# Epoch 13/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4952 - binary_accuracy: 0.7500
# Epoch 14/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4863 - binary_accuracy: 0.7500
# Epoch 15/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4793 - binary_accuracy: 0.7500
# Epoch 16/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4653 - binary_accuracy: 0.7500
# Epoch 17/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4619 - binary_accuracy: 0.7667
# Epoch 18/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4438 - binary_accuracy: 0.7833
# Epoch 19/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4380 - binary_accuracy: 0.7667
# Epoch 20/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4209 - binary_accuracy: 0.8167
# Epoch 21/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4036 - binary_accuracy: 0.8167
# Epoch 22/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4061 - binary_accuracy: 0.8333
# Epoch 23/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3857 - binary_accuracy: 0.8667
# Epoch 24/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3664 - binary_accuracy: 0.8667
# Epoch 25/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3403 - binary_accuracy: 0.8667
# Epoch 26/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3330 - binary_accuracy: 0.8833
# Epoch 27/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3303 - binary_accuracy: 0.8833
# Epoch 28/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3027 - binary_accuracy: 0.9000
# Epoch 29/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2773 - binary_accuracy: 0.9000
# Epoch 30/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2655 - binary_accuracy: 0.9167
# Epoch 31/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2538 - binary_accuracy: 0.9167
# Epoch 32/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2453 - binary_accuracy: 0.9333
# Epoch 33/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2304 - binary_accuracy: 0.9167
# Epoch 34/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2288 - binary_accuracy: 0.9000
# Epoch 35/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2175 - binary_accuracy: 0.9500
# Epoch 36/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2043 - binary_accuracy: 0.9333
# Epoch 37/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2019 - binary_accuracy: 0.9167
# Epoch 38/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1925 - binary_accuracy: 0.9167
# Epoch 39/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1829 - binary_accuracy: 0.9500
# Epoch 40/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1784 - binary_accuracy: 0.9667
# Epoch 41/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1816 - binary_accuracy: 0.9667
# Epoch 42/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1721 - binary_accuracy: 0.9500
# Epoch 43/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1707 - binary_accuracy: 0.9667
# Epoch 44/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1658 - binary_accuracy: 0.9667
# Epoch 45/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1580 - binary_accuracy: 0.9667
# Epoch 46/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1555 - binary_accuracy: 0.9500
# Epoch 47/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1534 - binary_accuracy: 0.9667
# Epoch 48/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1492 - binary_accuracy: 0.9667
# Epoch 49/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1447 - binary_accuracy: 0.9667
# Epoch 50/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1477 - binary_accuracy: 0.9667
# Epoch 51/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1438 - binary_accuracy: 0.9667
# Epoch 52/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1404 - binary_accuracy: 0.9500
# Epoch 53/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1409 - binary_accuracy: 0.9667
# Epoch 54/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1434 - binary_accuracy: 0.9667
# Epoch 55/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1513 - binary_accuracy: 0.9333
# Epoch 56/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1334 - binary_accuracy: 0.9333
# Epoch 57/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1344 - binary_accuracy: 0.9833
# Epoch 58/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1239 - binary_accuracy: 0.9833
# Epoch 59/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1264 - binary_accuracy: 0.9333
# Epoch 60/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1229 - binary_accuracy: 0.9667
# Epoch 61/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1204 - binary_accuracy: 0.9833
# Epoch 62/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1221 - binary_accuracy: 0.9667
# Epoch 63/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1234 - binary_accuracy: 0.9667
# Epoch 64/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1235 - binary_accuracy: 0.9500
# Epoch 65/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1107 - binary_accuracy: 0.9833
# Epoch 66/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1149 - binary_accuracy: 0.9667
# Epoch 67/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1132 - binary_accuracy: 0.9667
# Epoch 68/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1112 - binary_accuracy: 0.9833
# Epoch 69/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1113 - binary_accuracy: 0.9667
# Epoch 70/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1098 - binary_accuracy: 0.9833
# Epoch 71/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1108 - binary_accuracy: 0.9833
# Epoch 72/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1064 - binary_accuracy: 0.9833
# Epoch 73/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1169 - binary_accuracy: 0.9333
# Epoch 74/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1064 - binary_accuracy: 0.9667
# Epoch 75/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1095 - binary_accuracy: 0.9667
# Epoch 76/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1294 - binary_accuracy: 0.9333
# Epoch 77/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1057 - binary_accuracy: 0.9833
# Epoch 78/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1034 - binary_accuracy: 0.9667
# Epoch 79/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0955 - binary_accuracy: 1.0000
# Epoch 80/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0970 - binary_accuracy: 0.9667
# Epoch 81/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0926 - binary_accuracy: 0.9833
# Epoch 82/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0951 - binary_accuracy: 0.9667
# Epoch 83/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0900 - binary_accuracy: 0.9833
# Epoch 84/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0960 - binary_accuracy: 0.9667
# Epoch 85/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0889 - binary_accuracy: 0.9833
# Epoch 86/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0893 - binary_accuracy: 0.9833
# Epoch 87/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0957 - binary_accuracy: 1.0000
# Epoch 88/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0892 - binary_accuracy: 0.9833
# Epoch 89/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0966 - binary_accuracy: 0.9667
# Epoch 90/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1057 - binary_accuracy: 0.9500
# Epoch 91/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1039 - binary_accuracy: 0.9500
# Epoch 92/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1172 - binary_accuracy: 0.9667
# Epoch 93/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0982 - binary_accuracy: 0.9667
# Epoch 94/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0877 - binary_accuracy: 0.9667
# Epoch 95/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0790 - binary_accuracy: 1.0000
# Epoch 96/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0856 - binary_accuracy: 0.9667
# Epoch 97/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0798 - binary_accuracy: 0.9833
# Epoch 98/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0820 - binary_accuracy: 0.9833
# Epoch 99/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0741 - binary_accuracy: 1.0000
# Epoch 100/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0780 - binary_accuracy: 1.0000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4980 - binary_accuracy: 0.8500
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# Epoch 1/100
# 6/6 [==============================] - 0s 3ms/step - loss: 2.3517 - binary_accuracy: 0.5833
# Epoch 2/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1.0970 - binary_accuracy: 0.7000
# Epoch 3/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4815 - binary_accuracy: 0.8667
# Epoch 4/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2781 - binary_accuracy: 0.9333
# Epoch 5/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2491 - binary_accuracy: 0.9333
# Epoch 6/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2016 - binary_accuracy: 0.9500
# Epoch 7/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1787 - binary_accuracy: 0.9500
# Epoch 8/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1526 - binary_accuracy: 0.9500
# Epoch 9/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1335 - binary_accuracy: 0.9500
# Epoch 10/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1247 - binary_accuracy: 0.9500
# Epoch 11/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1193 - binary_accuracy: 0.9500
# Epoch 12/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1152 - binary_accuracy: 0.9500
# Epoch 13/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1101 - binary_accuracy: 0.9500
# Epoch 14/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1072 - binary_accuracy: 0.9500
# Epoch 15/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1029 - binary_accuracy: 0.9500
# Epoch 16/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1003 - binary_accuracy: 0.9500
# Epoch 17/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0974 - binary_accuracy: 0.9500
# Epoch 18/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0952 - binary_accuracy: 0.9500
# Epoch 19/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0923 - binary_accuracy: 0.9500
# Epoch 20/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0897 - binary_accuracy: 0.9500
# Epoch 21/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0872 - binary_accuracy: 0.9500
# Epoch 22/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0853 - binary_accuracy: 0.9500
# Epoch 23/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0835 - binary_accuracy: 0.9667
# Epoch 24/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0819 - binary_accuracy: 0.9667
# Epoch 25/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0811 - binary_accuracy: 0.9667
# Epoch 26/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0803 - binary_accuracy: 0.9667
# Epoch 27/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0792 - binary_accuracy: 0.9833
# Epoch 28/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0777 - binary_accuracy: 0.9833
# Epoch 29/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0766 - binary_accuracy: 0.9833
# Epoch 30/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0757 - binary_accuracy: 0.9833
# Epoch 31/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0749 - binary_accuracy: 0.9833
# Epoch 32/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0737 - binary_accuracy: 0.9833
# Epoch 33/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0731 - binary_accuracy: 0.9833
# Epoch 34/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0719 - binary_accuracy: 0.9833
# Epoch 35/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0718 - binary_accuracy: 0.9833
# Epoch 36/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0702 - binary_accuracy: 0.9833
# Epoch 37/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0691 - binary_accuracy: 0.9833
# Epoch 38/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0685 - binary_accuracy: 0.9833
# Epoch 39/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0674 - binary_accuracy: 0.9833
# Epoch 40/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0671 - binary_accuracy: 0.9833
# Epoch 41/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0664 - binary_accuracy: 0.9833
# Epoch 42/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0651 - binary_accuracy: 0.9833
# Epoch 43/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0645 - binary_accuracy: 0.9833
# Epoch 44/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0636 - binary_accuracy: 0.9833
# Epoch 45/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0637 - binary_accuracy: 0.9833
# Epoch 46/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0628 - binary_accuracy: 0.9833
# Epoch 47/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0618 - binary_accuracy: 0.9833
# Epoch 48/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0609 - binary_accuracy: 0.9833
# Epoch 49/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0606 - binary_accuracy: 0.9833
# Epoch 50/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0607 - binary_accuracy: 0.9833
# Epoch 51/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0597 - binary_accuracy: 0.9833
# Epoch 52/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0586 - binary_accuracy: 0.9833
# Epoch 53/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0578 - binary_accuracy: 0.9833
# Epoch 54/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0582 - binary_accuracy: 0.9833
# Epoch 55/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0573 - binary_accuracy: 0.9833
# Epoch 56/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0562 - binary_accuracy: 0.9833
# Epoch 57/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0556 - binary_accuracy: 0.9833
# Epoch 58/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0552 - binary_accuracy: 0.9833
# Epoch 59/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0548 - binary_accuracy: 0.9833
# Epoch 60/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0543 - binary_accuracy: 0.9833
# Epoch 61/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0542 - binary_accuracy: 0.9833
# Epoch 62/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0531 - binary_accuracy: 0.9833
# Epoch 63/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0528 - binary_accuracy: 0.9833
# Epoch 64/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0531 - binary_accuracy: 0.9833
# Epoch 65/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0521 - binary_accuracy: 0.9833
# Epoch 66/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0528 - binary_accuracy: 0.9833
# Epoch 67/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0513 - binary_accuracy: 0.9833
# Epoch 68/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0507 - binary_accuracy: 0.9833
# Epoch 69/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0508 - binary_accuracy: 0.9833
# Epoch 70/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0499 - binary_accuracy: 0.9833
# Epoch 71/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0500 - binary_accuracy: 0.9833
# Epoch 72/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0485 - binary_accuracy: 0.9833
# Epoch 73/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0485 - binary_accuracy: 0.9833
# Epoch 74/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0480 - binary_accuracy: 0.9833
# Epoch 75/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0483 - binary_accuracy: 0.9833
# Epoch 76/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0475 - binary_accuracy: 0.9833
# Epoch 77/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0466 - binary_accuracy: 0.9833
# Epoch 78/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0462 - binary_accuracy: 0.9833
# Epoch 79/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0465 - binary_accuracy: 0.9833
# Epoch 80/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0450 - binary_accuracy: 0.9833
# Epoch 81/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0447 - binary_accuracy: 0.9833
# Epoch 82/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0440 - binary_accuracy: 0.9833
# Epoch 83/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0442 - binary_accuracy: 0.9833
# Epoch 84/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0432 - binary_accuracy: 0.9833
# Epoch 85/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0431 - binary_accuracy: 0.9833
# Epoch 86/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0446 - binary_accuracy: 0.9833
# Epoch 87/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0426 - binary_accuracy: 0.9833
# Epoch 88/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0422 - binary_accuracy: 0.9833
# Epoch 89/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0421 - binary_accuracy: 0.9833
# Epoch 90/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0412 - binary_accuracy: 0.9833
# Epoch 91/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0420 - binary_accuracy: 0.9833
# Epoch 92/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0405 - binary_accuracy: 0.9833
# Epoch 93/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0408 - binary_accuracy: 0.9833
# Epoch 94/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0400 - binary_accuracy: 0.9833
# Epoch 95/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0396 - binary_accuracy: 0.9833
# Epoch 96/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0392 - binary_accuracy: 0.9833
# Epoch 97/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0392 - binary_accuracy: 0.9833
# Epoch 98/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0384 - binary_accuracy: 0.9833
# Epoch 99/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0385 - binary_accuracy: 0.9833
# Epoch 100/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0379 - binary_accuracy: 0.9833
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5102 - binary_accuracy: 0.9500
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# Epoch 1/100
# 6/6 [==============================] - 0s 4ms/step - loss: 4.6742 - binary_accuracy: 0.5000
# Epoch 2/100
# 6/6 [==============================] - 0s 2ms/step - loss: 2.7891 - binary_accuracy: 0.4833
# Epoch 3/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.2077 - binary_accuracy: 0.5500
# Epoch 4/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7719 - binary_accuracy: 0.5833
# Epoch 5/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6909 - binary_accuracy: 0.5833
# Epoch 6/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6914 - binary_accuracy: 0.5333
# Epoch 7/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6876 - binary_accuracy: 0.5333
# Epoch 8/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6812 - binary_accuracy: 0.5500
# Epoch 9/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6733 - binary_accuracy: 0.5833
# Epoch 10/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6670 - binary_accuracy: 0.6167
# Epoch 11/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6623 - binary_accuracy: 0.6167
# Epoch 12/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6538 - binary_accuracy: 0.5833
# Epoch 13/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6454 - binary_accuracy: 0.6167
# Epoch 14/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6397 - binary_accuracy: 0.6167
# Epoch 15/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6370 - binary_accuracy: 0.6333
# Epoch 16/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6331 - binary_accuracy: 0.6167
# Epoch 17/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6301 - binary_accuracy: 0.6167
# Epoch 18/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6259 - binary_accuracy: 0.6333
# Epoch 19/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6227 - binary_accuracy: 0.6500
# Epoch 20/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6195 - binary_accuracy: 0.6500
# Epoch 21/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6158 - binary_accuracy: 0.6667
# Epoch 22/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6100 - binary_accuracy: 0.6667
# Epoch 23/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6059 - binary_accuracy: 0.6833
# Epoch 24/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5998 - binary_accuracy: 0.6833
# Epoch 25/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5943 - binary_accuracy: 0.7000
# Epoch 26/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5852 - binary_accuracy: 0.7333
# Epoch 27/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5821 - binary_accuracy: 0.7167
# Epoch 28/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5727 - binary_accuracy: 0.7333
# Epoch 29/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5663 - binary_accuracy: 0.7333
# Epoch 30/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5567 - binary_accuracy: 0.7500
# Epoch 31/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5495 - binary_accuracy: 0.7500
# Epoch 32/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5434 - binary_accuracy: 0.7500
# Epoch 33/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5362 - binary_accuracy: 0.7500
# Epoch 34/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5314 - binary_accuracy: 0.7667
# Epoch 35/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5265 - binary_accuracy: 0.7667
# Epoch 36/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5203 - binary_accuracy: 0.7667
# Epoch 37/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5172 - binary_accuracy: 0.7667
# Epoch 38/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5090 - binary_accuracy: 0.7667
# Epoch 39/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5042 - binary_accuracy: 0.7667
# Epoch 40/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4979 - binary_accuracy: 0.7667
# Epoch 41/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4953 - binary_accuracy: 0.7833
# Epoch 42/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4897 - binary_accuracy: 0.7500
# Epoch 43/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4828 - binary_accuracy: 0.7833
# Epoch 44/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4711 - binary_accuracy: 0.8000
# Epoch 45/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4670 - binary_accuracy: 0.8167
# Epoch 46/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4584 - binary_accuracy: 0.8167
# Epoch 47/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4503 - binary_accuracy: 0.8333
# Epoch 48/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4439 - binary_accuracy: 0.8500
# Epoch 49/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4308 - binary_accuracy: 0.8833
# Epoch 50/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4164 - binary_accuracy: 0.9000
# Epoch 51/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4136 - binary_accuracy: 0.8833
# Epoch 52/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4006 - binary_accuracy: 0.9000
# Epoch 53/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3865 - binary_accuracy: 0.9167
# Epoch 54/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3728 - binary_accuracy: 0.9167
# Epoch 55/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3682 - binary_accuracy: 0.9167
# Epoch 56/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3559 - binary_accuracy: 0.9333
# Epoch 57/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3476 - binary_accuracy: 0.9500
# Epoch 58/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3358 - binary_accuracy: 0.9333
# Epoch 59/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3272 - binary_accuracy: 0.9167
# Epoch 60/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3240 - binary_accuracy: 0.9333
# Epoch 61/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3096 - binary_accuracy: 0.9333
# Epoch 62/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2996 - binary_accuracy: 0.9500
# Epoch 63/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2929 - binary_accuracy: 0.9500
# Epoch 64/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2853 - binary_accuracy: 0.9500
# Epoch 65/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2824 - binary_accuracy: 0.9500
# Epoch 66/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2679 - binary_accuracy: 0.9500
# Epoch 67/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2667 - binary_accuracy: 0.9333
# Epoch 68/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2540 - binary_accuracy: 0.9667
# Epoch 69/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2472 - binary_accuracy: 0.9667
# Epoch 70/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2410 - binary_accuracy: 0.9500
# Epoch 71/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2361 - binary_accuracy: 0.9500
# Epoch 72/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2262 - binary_accuracy: 0.9500
# Epoch 73/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2206 - binary_accuracy: 0.9833
# Epoch 74/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2276 - binary_accuracy: 0.9333
# Epoch 75/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2007 - binary_accuracy: 0.9833
# Epoch 76/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2027 - binary_accuracy: 0.9833
# Epoch 77/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1959 - binary_accuracy: 0.9833
# Epoch 78/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1932 - binary_accuracy: 0.9500
# Epoch 79/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1916 - binary_accuracy: 0.9667
# Epoch 80/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1785 - binary_accuracy: 0.9833
# Epoch 81/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1739 - binary_accuracy: 0.9667
# Epoch 82/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1616 - binary_accuracy: 0.9833
# Epoch 83/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1591 - binary_accuracy: 0.9833
# Epoch 84/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1552 - binary_accuracy: 0.9833
# Epoch 85/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1531 - binary_accuracy: 0.9667
# Epoch 86/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1454 - binary_accuracy: 0.9833
# Epoch 87/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1489 - binary_accuracy: 1.0000
# Epoch 88/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1521 - binary_accuracy: 0.9833
# Epoch 89/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1390 - binary_accuracy: 0.9833
# Epoch 90/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1399 - binary_accuracy: 1.0000
# Epoch 91/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1449 - binary_accuracy: 0.9500
# Epoch 92/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1307 - binary_accuracy: 0.9833
# Epoch 93/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1221 - binary_accuracy: 0.9833
# Epoch 94/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1194 - binary_accuracy: 0.9667
# Epoch 95/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1167 - binary_accuracy: 1.0000
# Epoch 96/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1122 - binary_accuracy: 1.0000
# Epoch 97/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1084 - binary_accuracy: 1.0000
# Epoch 98/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1018 - binary_accuracy: 1.0000
# Epoch 99/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1001 - binary_accuracy: 1.0000
# Epoch 100/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1073 - binary_accuracy: 0.9833
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3337 - binary_accuracy: 0.8500
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
